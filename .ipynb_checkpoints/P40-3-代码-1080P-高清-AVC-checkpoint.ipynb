# %%
# 1、模型选择、欠拟合和过拟合
# 通过多项式拟合来交互地探索这些概念

# %%
import math
import numpy as np
import torch
from torch import nn
from d2l import torch as d2l

# %%
# 使用以下三阶多项式来生成训练和测试数据的标签：

# %% [markdown]
# ![gs](./assets/gs.jpg)

# %%
max_degree = 20  # 多项式的最大阶数
n_train, n_test = 100, 100  # 训练和测试数据集大小
true_w = np.zeros(max_degree)  # 分配大量的空间
true_w[0:4] = np.array([5, 1.2, -3.4, 5.6]) #第4项之后的系数均为0

features = np.random.normal(size=(n_train + n_test, 1))
np.random.shuffle(features)  # 随机排序features
poly_features = np.power(features, np.arange(max_degree).reshape(1, -1))
# 使用 np.power() 函数将 features 数组中的元素分别取不同幂次（从 0 到 max_degree-1）
# 结果保存在 poly_features 数组中，每行为某一feature的不同幂次结果
for i in range(max_degree):
    poly_features[:, i] /= math.gamma(i + 1)  # gamma(n)=(n-1)!
    # 按列对poly_features中相同幂次的元素除以相应的阶乘
# labels的维度:(n_train+n_test)，详见下方print shape
labels = np.dot(poly_features, true_w)
labels += np.random.normal(scale=0.1, size=labels.shape) #添加随机噪声

# %%
# NumPy ndarray转换为tensor
true_w, features, poly_features, labels = [torch.tensor(x, dtype=
    torch.float32) for x in [true_w, features, poly_features, labels]]
features[:2], poly_features[:2, :], labels[:2] #lables的shape为[1, 200]
# Out:
# (tensor([[0.2986],
#          [0.9186]]),
#  tensor([[1.0000e+00, 2.9857e-01, 4.4573e-02, 4.4361e-03, 3.3113e-04, 1.9773e-05,
#           9.8396e-07, 4.1969e-08, 1.5664e-09, 5.1964e-11, 1.5515e-12, 4.2113e-14,
#           1.0478e-15, 2.4065e-17, 5.1323e-19, 1.0216e-20, 1.9064e-22, 3.3482e-24,
#           5.5538e-26, 8.7274e-28],
#          [1.0000e+00, 9.1855e-01, 4.2187e-01, 1.2917e-01, 2.9662e-02, 5.4493e-03,
#           8.3424e-04, 1.0947e-04, 1.2569e-05, 1.2828e-06, 1.1784e-07, 9.8399e-09,
#           7.5320e-10, 5.3220e-11, 3.4918e-12, 2.1383e-13, 1.2276e-14, 6.6329e-16,
#           3.3848e-17, 1.6364e-18]]),
#  tensor([5.1829, 5.4234]))

# %%
# 对模型进行训练和测试
# 实现一个函数来评估模型在给定数据集上的损失

# %%
def evaluate_loss(net, data_iter, loss):  #@save
    """评估给定数据集上模型的损失"""
    metric = d2l.Accumulator(2)  
    for X, y in data_iter:
        out = net(X)
        y = y.reshape(out.shape)
        l = loss(out, y)
        metric.add(l.sum(), l.numel()) # 累计损失的总和以及样本数量
    return metric[0] / metric[1] # 计算损失平均值

# %%
# 定义训练函数

# %%
def train(train_features, test_features, train_labels, test_labels,
          num_epochs=400):
    loss = nn.MSELoss(reduction='none')
    input_shape = train_features.shape[-1]
    # 不设置偏置，因为我们已经在多项式中实现了它
    net = nn.Sequential(nn.Linear(input_shape, 1, bias=False))
    batch_size = min(10, train_labels.shape[0]) # 防止最后剩下的size不足10
    train_iter = d2l.load_array((train_features, train_labels.reshape(-1,1)),
                                batch_size)
    test_iter = d2l.load_array((test_features, test_labels.reshape(-1,1)),
                               batch_size, is_train=False)
    trainer = torch.optim.SGD(net.parameters(), lr=0.01)
    animator = d2l.Animator(xlabel='epoch', ylabel='loss', yscale='log',
                            xlim=[1, num_epochs], ylim=[1e-3, 1e2],
                            legend=['train', 'test'])
    for epoch in range(num_epochs):
        d2l.train_epoch_ch3(net, train_iter, loss, trainer)
        # 记录初始损失值，此后每隔20个epochs记录一次损失值
        if epoch == 0 or (epoch + 1) % 20 == 0:
            animator.add(epoch + 1, (evaluate_loss(net, train_iter, loss),
                                     evaluate_loss(net, test_iter, loss)))
    # 打印第一层的权重值
    print('weight:', net[0].weight.data.numpy())

# %%
# 三阶多项式函数拟合(正常)

# %%
# 从多项式特征中选择前4个维度，即1,x,x^2/2!,x^3/3!
train(poly_features[:n_train, :4], poly_features[n_train:, :4],
      labels[:n_train], labels[n_train:])
# Out:
# weight: [[ 4.9917865  1.1904951 -3.3828466  5.602126 ]]

# %%
# 线性函数拟合(欠拟合)

# %%
# 从多项式特征中选择前2个维度，即1和x
train(poly_features[:n_train, :2], poly_features[n_train:, :2],
      labels[:n_train], labels[n_train:])
# Out:
# weight: [[3.5334194 3.6120577]]

# %%
# 高阶多项式函数拟合(过拟合)

# %%
# 从多项式特征中选取所有维度
train(poly_features[:n_train, :], poly_features[n_train:, :],
      labels[:n_train], labels[n_train:], num_epochs=1500)
# Out:
# weight: [[ 4.9692445   1.2422988  -3.247687    5.2410517  -0.49488547  1.3136536
#    0.08175616  0.23482816  0.12885875  0.05726367 -0.18756548  0.19714655
#   -0.17244591 -0.16725601 -0.03341565 -0.2009712  -0.20596102 -0.16963258
#    0.09190992 -0.14856043]]
